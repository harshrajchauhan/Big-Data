# %% [markdown]
# # Accessing existing tables in Spark

# %% [markdown]
# In this notebook we will access the Boston dataset stored in Spark warehouse in previous notebook.

# %%
sc = spark.sparkContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %% [markdown]
# Display the spark object - this provides the link to the Spark UI

# %%
spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %% [markdown]
# List the Spark datawarehouse. It should show the default database.

# %%
spark.catalog.listTables()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %%
df=spark.sql("show databases;") 
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %% [markdown]
# List the tables in the database. If this is a new install (you haven't run this notebook before), there shouldn't be any tables.

# %%
tables = spark.sql("show tables").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %% [markdown]
# We can use SQL to query the table. The result is a dataframe.

# %%
df = spark.sql("select * from w10_db.boston")
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %% [markdown]
# But notice that the temp view is not available...

# %%
#boston.createOrReplaceTempView("boston_tmp_view")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %%
spark.catalog.listTables()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %%
spark.catalog.listTables('w10_db')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %%
spark.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.lang.RuntimeException: abort: DriverClient destroyed
# 	at com.databricks.backend.daemon.driver.DriverClient.$anonfun$poll$4(DriverClient.scala:671)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:54)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:77)
# 	at com.databricks.threading.DatabricksExecutionContext$InstrumentedRunnable.run(DatabricksExecutionContext.scala:36)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$2(NamedExecutor.scala:463)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:441)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:248)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:244)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:439)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:436)
# 	at com.databricks.threading.NamedExecutor.withAttributionContext(NamedExecutor.scala:370)
# 	at com.databricks.threading.NamedExecutor$$anon$2.$anonfun$run$1(NamedExecutor.scala:454)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:72)
# 	at com.databricks.threading.NamedExecutor$$anon$2.run(NamedExecutor.scala:453)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
